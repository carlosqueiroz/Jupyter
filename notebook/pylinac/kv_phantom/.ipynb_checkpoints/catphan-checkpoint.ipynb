# %%
from pylinac import CatPhan504
CatPhan504.run_demo() # the demo is a Varian high quality head scan
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  - CatPhan 504 QA Test -
# HU Linearity ROIs: Air: -998.0, PMP: -200.0, LDPE: -102.0, Poly: -45.0, Acrylic: 115.0, Delrin: 340.0, Teflon: 997.0
# HU Passed?: True
# Low contrast visibility: 3.46
# ...

# %%
from pylinac.ct import CTP515, CTP486
cbct_folder = "dcm/CT_PHILIPS"
#mycbct = CatPhan504(cbct_folder)

class PartialCatPhan504(CatPhan504):
    modules = {
        CTP486: {'offset': -65},
        CTP515: {'offset': -30},
        # the CTP528 was omitted
    }

ct = PartialCatPhan504(cbct_folder)  # use like normal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-11a0c7545626> in <module>
#       3 #mycbct = CatPhan504(cbct_folder)
#       4
# ----> 5 class PartialCatPhan504(CatPhan504):
#       6     modules = {
#       7        # CTP486: {'offset': -65},
#
# <ipython-input-8-11a0c7545626> in PartialCatPhan504()
#       6     modules = {
#       7        # CTP486: {'offset': -65},
# ----> 8         CTP404: {'offset': -30},
#       9         # the CTP528 was omitted
#      10     }
#
# NameError: name 'CTP404' is not defined
