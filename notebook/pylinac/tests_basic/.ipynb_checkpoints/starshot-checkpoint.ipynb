# %%
import os
import shutil
import subprocess
import logging
from time import time
import multiprocessing
from pprint import pprint
import collections

import json
import pydicom
import numpy as np
from scipy.sparse import csc_matrix
import math
import matplotlib.pyplot as plt
import numpy.matlib
from scipy import interpolate
from datetime import datetime

import os.path as osp
import tempfile
from unittest import TestCase

import matplotlib.pyplot as plt
import numpy as np

from pylinac.core.geometry import Point
from pylinac import Starshot
from tests_basic.utils import save_file, LoadingTestBase, LocationMixin

plt.close('all')
TEST_DIR = osp.join('/', 'test_files', 'Starshot')

SOPClassUIDs = {
    'CR': [
        '1.2.840.10008.5.1.4.1.1.1', #CR Storage 
        '1.2.840.10008.5.1.4.1.1.1.1', #CR Presentation 
        '1.2.840.10008.5.1.4.1.1.1.1.1' #CR Processing
    ],
    'XC': [
        '1.2.840.10008.5.1.4.1.1.77.1.4' #CR Storage 
    ],
 
}



class StarshotRead:
    def __init__(self, InFolder):
        day = datetime.today().strftime('%Y/%m/%d')
        base_path = "/var/www/public/uploads/dcmtk/"+day
        tmp = InFolder.rpartition('/') # seriesUidHash
        tmp2 = tmp[0].rpartition('/')  # studyUidHash

        self.InFolder = InFolder
        self.BasePath = base_path + '/' + tmp2[2] + '/' + tmp[2]
        kwargs = {'dpi': 30, 'sid': 1000}
        
        self.seriesInstanceUid = ''
        self.fileString = ''
 
        
    def load_files(self):
        ret = []
        for dirName, subdirList, fileList in os.walk(self.InFolder):
            for filename in fileList:
            
                file = os.path.join(dirName, filename)
                ret.append(file)
                tmp_file = pydicom.dcmread(file, force=True, specific_tags=['SOPClassUID'])
                if "PatientsName" in tmp_file:
               
                    if tmp_file.SOPClassUID in SOPClassUIDs['CR']:
                        ret.append(file)

                       #self.seriesInstanceUid = tmp_file.SeriesInstanceUID
                    elif tmp_file.SOPClassUID in SOPClassUIDs['XC']:
                        ret.append(file)
                       # self.seriesInstanceUid = tmp_file.SeriesInstanceUID
                    else:
                        break
        self.fileString = ' '.join(ret)
        return ret
    
    def getParameters(self):
        files = self.load_files()
        for file in files:
            print("____________________________________________________________________")
            print("LINKS:")
            print('http://192.168.10.195:1515/files/pylinac/tests_basic/'+file+'.png')
            print("Abrir pdf e salvar pc para visualizar, pelo navegador pdf não abre!!")
            print('http://192.168.10.195:1515/files/pylinac/tests_basic/'+file+'.pdf')
            print("RESULTADOS:")
            mystar = Starshot(file, sid=1000, radius: float = 0.85)
            mystar.analyze()
            print(mystar.results())
            mystar.plot_analyzed_image()
            mystar.save_analyzed_image(file+'.png')
            mystar.publish_pdf(file+'.pdf')
   

        
 
     

mpr = StarshotRead('test_files/Starshot/teste')
mpr.getParameters()
# Out:
# ____________________________________________________________________
# LINKS:
# http://192.168.10.195:1515/files/pylinac/tests_basic/test_files/Starshot/teste/1.png
# Abrir pdf e salvar pc para visualizar, pelo navegador pdf não abre!!
# http://192.168.10.195:1515/files/pylinac/tests_basic/test_files/Starshot/teste/1.pdf
# RESULTADOS:
#
# Result: PASS
#
# The minimum circle that touches all the star lines has a diameter of 0.267 mm.
#
# The center of the minimum circle is at 1024.1, 1250.2
# ____________________________________________________________________
# LINKS:
# http://192.168.10.195:1515/files/pylinac/tests_basic/test_files/Starshot/teste/2.png.png
# Abrir pdf e salvar pc para visualizar, pelo navegador pdf não abre!!
# http://192.168.10.195:1515/files/pylinac/tests_basic/test_files/Starshot/teste/2.png.pdf
# RESULTADOS:
#
# Result: PASS
#
# The minimum circle that touches all the star lines has a diameter of 0.708 mm.
#
# The center of the minimum circle is at 147.1, 142.7
# ____________________________________________________________________
# LINKS:
# http://192.168.10.195:1515/files/pylinac/tests_basic/test_files/Starshot/teste/3.png
# Abrir pdf e salvar pc para visualizar, pelo navegador pdf não abre!!
# http://192.168.10.195:1515/files/pylinac/tests_basic/test_files/Starshot/teste/3.pdf
# RESULTADOS:
#
# Result: FAIL
#
# The minimum circle that touches all the star lines has a diameter of 1.628 mm.
#
# The center of the minimum circle is at 1027.0, 1250.8
# ____________________________________________________________________
# LINKS:
# http://192.168.10.195:1515/files/pylinac/tests_basic/test_files/Starshot/teste/1.pdf.png
# Abrir pdf e salvar pc para visualizar, pelo navegador pdf não abre!!
# http://192.168.10.195:1515/files/pylinac/tests_basic/test_files/Starshot/teste/1.pdf.pdf
# RESULTADOS:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-dd5cc2d469fa> in <module>
#     105
#     106 mpr = StarshotRead('test_files/Starshot/teste')
# --> 107 mpr.getParameters()
#
# <ipython-input-122-dd5cc2d469fa> in getParameters(self)
#      92             print('http://192.168.10.195:1515/files/pylinac/tests_basic/'+file+'.pdf')
#      93             print("RESULTADOS:")
# ---> 94             mystar = Starshot(file, sid=1000)
#      95             mystar.analyze()
#      96             print(mystar.results())
#
# /opt/conda/lib/python3.7/site-packages/pylinac/starshot.py in __init__(self, filepath, **kwargs)
#      71             Passed to :func:`~pylinac.core.image.load`.
#      72         """
# ---> 73         self.image = image.load(filepath, **kwargs)
#      74         self.wobble = Wobble()
#      75         self.tolerance = 1
#
# /opt/conda/lib/python3.7/site-packages/pylinac/core/image.py in load(path, **kwargs)
#     156         return FileImage(path, **kwargs)
#     157     else:
# --> 158         raise TypeError(f"The argument `{path}` was not found to be a valid DICOM file, Image file, or array")
#     159
#     160
#
# TypeError: The argument `test_files/Starshot/teste/1.pdf` was not found to be a valid DICOM file, Image file, or array
